# %% [markdown]
# 24

# %%
tup =24
print(tup)
# Out:
# 24

# %%
tup=20,
print(tup)
print(type(tup))
# Out:
# (20,)
# <class 'tuple'>

# %%
tup = ("arti",20,3.6)
print(tup)
print(type(tup))
# Out:
# ('arti', 20, 3.6)
# <class 'tuple'>

# %%
tup.
