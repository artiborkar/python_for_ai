# %% [markdown]
# ## login building

# %%
total = 0
for n in [3,5,2]:
    total=total+n
print(total)
# Out:
# 10

# %% [markdown]
# ## class 2

# %% [markdown]
# ### LOGIC CLASS 2 — Pseudocode: Python se PEHLE English mein socho

# %% [markdown]
# ####  Concept 1 — Problem: "3 numbers mein sabse bada"

# %% [markdown]
# step 1 : restate = mere pass 3 number hai ya 3 number milenge to muze sabse bda number print karna hai.
# step 2 : Example = a,b,c=5,7,3 or user se bhi le sakte hai bas input function lena hai.
# step 3 : psuedocode = 1. define 3 veriable a,b,c and assign the value
#                       2. then assign 4 varible biggest=a.
#                       3. then check the if statement b is grather than biggest the condition is true the n executed biggest=b but condtion is false the the check sencond if statement .
#                       4. if c is grather than biggest then the condition is true then next line excute the condtion is false then
#                       5. print the biggest number.
#                       6. show the answer.
# step 4 : Translate =

# %%
# step 4 : Translate = 

a,b,c  =  6,12,9
biggest = 0

if a > biggest:     #6>0==t
    biggest=a          #6
if b > biggest:       #12>6==t
    biggest=b           #12
if c > biggest:           #9>12==f
    biggest= c

print(f"Biggest Number is : {biggest}")         #12
# Out:
# Biggest Number is : 12

# %% [markdown]
# step 5 : trace (dry run) =
# step  a   b   c    biggest
# 1     6   12   9
# 2     6    12  9     0
# 3     6    12   9    6
# 4     6     12   9    12
# 5     6     12    9    12
# print====12

# %% [markdown]
# #### Concept 2 — Ek aur: "Even ya Odd batao 1 se 10 tak"

# %% [markdown]
# step 1 : restate = check even or odd number.
# step 2 : Example =
# step 3 : psuedocode = 1. define 3 veriable a,b,c and assign the value
#                       2. then assign 4 varible biggest=a.
#                       3. then check the if statement b is grather than biggest the condition is true the n executed biggest=b but condtion is false the the check sencond if statement .
#                       4. if c is grather than biggest then the condition is true then next line excute the condtion is false then
#                       5. print the biggest number.
#                       6. show the answer.
# step 4 : Translate =
