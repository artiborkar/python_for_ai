# %% [markdown]
# # Professional Workflow

# %% [markdown]
# ## CLASS 66 - Virtual Environment & pip

# %% [markdown]
# #### Concept 1-virtural environment aur pip kya hain aur  kyun

# %% [markdown]
# pip ---package installer for python

# %% [markdown]
# PyPI---Python package Index

# %% [markdown]
# #### Concept -2 venv banao aur activate karo

# %% [markdown]
# #### Concept 3- package install karo (pip)

# %% [markdown]
# #### Concept -4 -requirements.txt (project ki shopping list)

# %% [markdown]
# ### DEMO - naya project setup

# %%
# mkdir my_agent_project
# cd my_agent_project
# python -m venv .venv
# .venv\Script\activate.ps1
# pip install requests
# pip freeze > requirements.txt
# deactivate

# %% [markdown]
# ## CLASS 67 -- Modern Packaging & Lazy imports

# %% [markdown]
# #### Concept 1 - pyproject.toml (project ka ID card)

# %% [markdown]
# #### Concept -2 -(super -fast modern tool)

# %% [markdown]
# case 1 project mein requirements.txt hai (Traditional Repo)

# %% [markdown]
# cd exixting_company_project
#
# # fast .venv banao aur requirement.txt install karo:
# uv venv
# # windows:.venv\Script\Activate.ps1 | Mac/Linux : source .venv/bin/activate
# uv pip install -r requirements.txt

# %% [markdown]
# case 2: company project ko modern uv (pyproject.toml) mein migrate karna ho:

# %% [markdown]
# cd existing_company_project
#
# #1. Existing folder mein pyproject.toml add karo
# uv init --bare
#
# #2.Existing requirement.txt ke package pyproject.toml mein import karo
# uv add -r requirements.txt
#
# #3.Exact lockfile aur environment create karo:
# uv sync

# %% [markdown]
# #### concept 3- semantic versioning (>=,==,~=)

# %% [markdown]
# MAJAR . MINOR . PATCH
# 3.14.0     (3--majar.14--minor.0--patch)
#
# 3---ye number tb pdta hai jb bhut pda change hota hai application mai.
#
# 14----jb koi feature add hota hai hmare application main tb is number mai change hota hai.
#
# 0----jb hmare code mai error or bug aata hai or hm resolve karte hai tb is number main chnage hota hai.

# %% [markdown]
# requests>=2.32   #2.32 ya usse naya
# requests==2.32.0   #bilkul yani version (exact)
# requests~=2.32   #2.32 se compatible (2.x , par 3.0 nhi)

# %% [markdown]
# #### concept -4-lazy imports (python 3.15)

# %% [markdown]
# ## CLASS 68 ---Project Structure

# %% [markdown]
# #### Concept 1- k achha project kaise dekhta hai

# %% [markdown]
# my_agent_project/
# |___ .venv/            #virtual environment (Git mein NAHI)
# |___ src/              #saare source code yahan
# |    |--__init__.py    #batata hai 'yeh ek package hai'
# |    |--tools.py       #tool function
# |    |--agent.py       #agent class
# |    |--main.py        #entry point (program yahan se chalta hai)
# |___ tests/            #test files(week 13)
# |    |__test_tools.py
# |___ .env              #secrets (git mein NAHI)
# |___ gitignore        #Git ko batata hai kya ignore kare
# |___ requirements.txt  #ya pyproject.toml
# |___ README.md          #project ka description

# %% [markdown]
# #### concept 2- __init__.py(folder ko package banao)

# %% [markdown]
# #### concept 3- README.md (project ka chehra)

# %% [markdown]
# ### concept 4- .gitignor (kya Git mein NA jaaye)

# %% [markdown]
# ## CLASS 69- Git & GitHub

# %% [markdown]
# #### concept -1  git kya karta hai

# %% [markdown]
# #### concept-2 basic git workflow (4 coomand)

# %% [markdown]
# #### concept-3-commit messages (achhe likho)

# %%
# git commit -m "feature:add calculateor tool"-----------saaff,tarika .batata hai kya hua
# git commit -m "add calculator-------bekaar --kuch mahine bad samaj nhi aayega"

# %% [markdown]
# #### Concept--4--history dekho aur branches

# %% [markdown]
# #### concept -5 -GitHub par push

# %% [markdown]
# #### concept 6- pehele .gitignore (secreats push mat karo)

# %% [markdown]
# ## CLASS 70- Secrets & Profiling (project Class)

# %% [markdown]
# #### concept -1 -secrets KABHI code mein nahi

# %% [markdown]
# #### concept-2- .env file (secrets ka safe ghar)

# %% [markdown]
# is filr mai password store krna hota hai.
# .env--environment variable
#
#
# import os
# from dotenv import load_dotenv
#
# load_dotenv()
#
# p_w = os.getenv("password)

# %% [markdown]
# #### concept -3 -.env.example (template , bina secrets)

# %% [markdown]
# #### concept -4 profiling (slow hisse dhoondho)
