# %%
x=10
for i in  range(3):
    x=x-2
print(x)
# Out:
# 4

# %%
result =" "
for c in "cat":
    result=c+result
print(result)
# Out:
# tac

# %%
nums=[4,1,7,8]
biggest=nums[0]
for n in nums:
    if n>biggest:
        biggest=n
print(biggest)
# Out:
# 8

# %%
s=0
for i in range(1,6):
    if i%2==0:
        s=s+i
print(s)
# Out:
# 6
