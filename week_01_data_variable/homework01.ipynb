# %%
##print the all math formulas homework one
##Pythagorean Theorem 

a=5
b=6
c=(a**a) + b**b
print(f"The Pythagorean Theorem is {c}")
# Out:
# The Pythagorean Theorem is 49781

# %%
##Area of a circle
r=6
A=3.14*r**r
print(f"The Area of a circle is {A}")


##Area of a triangle
b=7
h=25
A=1/2*b*h
print(f"Area of Triangle is{A}")
# Out:
# The Area of a circle is 146499.84
# Area of Triangle is87.5

# %%
##Area of paralleogram
b=4
h=7
A=b*h
print(f"Area of paralleogram {A}")
# Out:
# Area of paralleogram 28

# %%
mark=56.8756
print(f"my mark is {mark:.2f}")
# Out:
# my mark is 56.88

# %%
##bollean opertor
arti_is_girl=True
navneet_is_girl=False
one=True
zero=False
print(f"arti is girl {arti_is_girl}")
print(f"naveent is girl {navneet_is_girl}")
print(f"one number is {one}")
print(f"zero number is {zero}")
# Out:
# arti is girl True
# naveent is girl False
# one number is True
# zero number is False

# %%
##comparison operators

"arti" == "arti"
# Out:
# True

# %%
"arti" != "arti"
# Out:
# False

# %%
9 > 23
# Out:
# False

# %%
9 < 23
# Out:
# True

# %%
34 >= 43
# Out:
# False

# %%
34 <= 43
# Out:
# True

# %% [markdown]
# ###logical opreater

# %%
a=True
b=False
c=a and b
d=a or b
e=not b
print(f"and opreater retrurn {c}")
print(f"or operater return {d}")
print(f"not opretor {e}")
print
# Out:
# and opreater retrurn False
# or operater return True
# not opretor True
# <function print(*objects, sep=' ', end='\n', file=None, flush=False)>

# %%
1 and 0
# Out:
# 0

# %%
4 and True
# Out:
# True

# %%
0 or 0
# Out:
# 0

# %%
0 or 1
# Out:
# 1

# %%
not 1
# Out:
# False

# %%
not 0
# Out:
# True

# %% [markdown]
# # type()

# %%
type("Arti")
# Out:
# str

# %%
type(232534)
# Out:
# int

# %%
type(15652.212)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %% [markdown]
# # convert type

# %%
num=213
num2=str(num)
print(type(num))
print(type(num2))
# Out:
# <class 'int'>
# <class 'str'>

# %%
name="Arti"
# name1=int(name)      
print(type(name))
# print(type(name1))    #error show kregaa
# Out:
# <class 'str'>

# %%
value=33
value1=float(value)
print(type(value))
print(type(value1))
value2=46+84
value3=float(value2)
print(value3)
# Out:
# <class 'int'>
# <class 'float'>
# 130.0

# %%
value=46.4+84.7
value2=int(value)
print(value)
print(value2)
print(type(value))
print(type(value2))
# Out:
# 131.1
# 131
# <class 'float'>
# <class 'int'>

# %% [markdown]
# ## input()

# %%
a="Arti"
print(a)
b="Borkar"
print(b)
input()
c="Mandgaon"
print(c)
# Out:
# Arti
# Borkar
# Mandgaon

# %%
name=input("Enter your name:")
age=input("Enter your age:")
city=input("Enter your city:")
print(name)
print(age)
print(city)
# Out:
# Arti
# 20
# Mandgaon

# %% [markdown]
# ###Homework

# %%
num=input("Enter your number:")
CLASS=input("Enter your class:")
mark=input("Enter your mark:")
per=input("Enter your percentage:")
sub=input("Enter your subject:")
song=input("Enter your song:")
print(num)
print(CLASS)
print(mark)
print(per)
print(sub)
print(song)
# Out:
# 21
# 12TH
# 350
# 54
# MATH
# lal color chi bangdi

# %%
"Arti "  *  100
# Out:
# 'Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti Arti '

# %% [markdown]
# ## string method

# %%
"Arti".upper()
# Out:
# 'ARTI'

# %%
'ARTI'.lower()
# Out:
# 'arti'

# %%
"Arti".title()
# Out:
# 'Arti'

# %%
" Arti ".strip()        # strip mean blank space remove
# Out:
# 'Arti'

# %%
" Arti ".lstrip()
# Out:
# 'Arti '

# %%
" Arti ".rstrip()
# Out:
# ' Arti'

# %% [markdown]
# #UTF 8

# %%
heyy= " नमस्ते ✋ Hello "
print(heyy)
# Out:
#  नमस्ते ✋ Hello

# %%
num1=5
num2=6
num3=num1**num2
print(num3)
# Out:
# 15625
