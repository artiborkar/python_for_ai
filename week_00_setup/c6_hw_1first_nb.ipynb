# %% [markdown]
# #### Cursor mein first_notebook.ipynb banao aur 2 code cells chalao.

# %%
print("Hello Ai")
print("my name is AI")
# Out:
# Hello Ai
# my name is AI

# %%
print("my name is arti")
# Out:
# my name is arti

# %%
print("I am a girl")
# Out:
# I am a girl
